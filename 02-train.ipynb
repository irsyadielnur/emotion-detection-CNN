# %%
import os
import cv2
import numpy as np # linear algebra
import pandas as pd #
import matplotlib.pyplot as plt 
import seaborn as sns
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, GlobalAveragePooling2D, Input, Activation
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all train images
train_generator = train_data_gen.flow_from_directory(
        'D:/Kuliah Files/Semester 7/Machine Learning/Emotion_detection_CNN/data/train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode="categorical",
        shuffle=True)

# Preprocess all test images
validation_generator = validation_data_gen.flow_from_directory(
        'D:/Kuliah Files/Semester 7/Machine Learning/Emotion_detection_CNN/data/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode="categorical",
        shuffle=False)
# Out:
# Found 29200 images belonging to 7 classes.
# Found 7300 images belonging to 7 classes.

# %%
emotion_model = Sequential()

# Input layer
emotion_model.add(Conv2D(64, kernel_size=(3,3), padding= 'same', input_shape=(48, 48, 1)))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(MaxPooling2D(pool_size=(2,2)))
emotion_model.add(Dropout(0.25))

# Hidden layer 1
emotion_model.add(Conv2D(128, kernel_size=(5,5), padding= 'same'))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

# Hidden layer 2
emotion_model.add(Conv2D(512, kernel_size=(3, 3), padding= 'same'))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

# Hidden layer 3
emotion_model.add(Conv2D(512, kernel_size=(3, 3), padding= 'same'))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

# Flatten Layer
emotion_model.add(Flatten())

# Fully Connected layer
emotion_model.add(Dense(256))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(Dropout(0.25))

# Fully Connected layer
emotion_model.add(Dense(512))
emotion_model.add(BatchNormalization())
emotion_model.add(Activation('relu'))
emotion_model.add(Dropout(0.25))

emotion_model.add(Dense(7, activation='softmax'))

cv2.ocl.setUseOpenCL(False)

emotion_model.compile(loss='categorical_crossentropy', 
                        optimizer=Adam(learning_rate=0.0001), 
                        metrics=['accuracy'])
emotion_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 24, 24, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 12, 12, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 12, 12, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,478,727 (17.08 MB)
#  Trainable params: 4,474,759 (17.07 MB)
#  Non-trainable params: 3,968 (15.50 KB)

# %%
emotion_model_info = emotion_model.fit (
        train_generator,
        steps_per_epoch=train_generator.n//64,
        epochs=75,
        validation_data=validation_generator,
        validation_steps=validation_generator.n//64)
# Out:
# C:\Users\acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 2306s 5s/step - accuracy: 0.2086 - loss: 2.1164 - val_accuracy: 0.1711 - val_loss: 1.9510
# Epoch 2/75
#   1/456 ━━━━━━━━━━━━━━━━━━━━ 16:33 2s/step - accuracy: 0.3125 - loss: 1.8620
# C:\Users\acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 78s 166ms/step - accuracy: 0.3125 - loss: 1.8620 - val_accuracy: 0.1717 - val_loss: 1.9537
# Epoch 3/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 892s 2s/step - accuracy: 0.2903 - loss: 1.8563 - val_accuracy: 0.3317 - val_loss: 1.7505
# Epoch 4/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 129ms/step - accuracy: 0.3125 - loss: 1.8321 - val_accuracy: 0.3320 - val_loss: 1.7532
# Epoch 5/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 943s 2s/step - accuracy: 0.3428 - loss: 1.7263 - val_accuracy: 0.3411 - val_loss: 1.8047
# Epoch 6/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 59s 125ms/step - accuracy: 0.3438 - loss: 1.6772 - val_accuracy: 0.3422 - val_loss: 1.8099
# Epoch 7/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 957s 2s/step - accuracy: 0.3734 - loss: 1.6406 - val_accuracy: 0.3894 - val_loss: 1.6413
# Epoch 8/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 64s 136ms/step - accuracy: 0.4219 - loss: 1.6158 - val_accuracy: 0.3902 - val_loss: 1.6402
# Epoch 9/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 941s 2s/step - accuracy: 0.4054 - loss: 1.5650 - val_accuracy: 0.3983 - val_loss: 1.6224
# Epoch 10/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - accuracy: 0.4688 - loss: 1.3469 - val_accuracy: 0.3975 - val_loss: 1.6247
# Epoch 11/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 942s 2s/step - accuracy: 0.4292 - loss: 1.4909 - val_accuracy: 0.4282 - val_loss: 1.5467
# Epoch 12/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 128ms/step - accuracy: 0.4375 - loss: 1.4165 - val_accuracy: 0.4289 - val_loss: 1.5459
# Epoch 13/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 956s 2s/step - accuracy: 0.4495 - loss: 1.4279 - val_accuracy: 0.4746 - val_loss: 1.3671
# Epoch 14/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.4844 - loss: 1.3865 - val_accuracy: 0.4752 - val_loss: 1.3659
# Epoch 15/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 948s 2s/step - accuracy: 0.4761 - loss: 1.3719 - val_accuracy: 0.4989 - val_loss: 1.3110
# Epoch 16/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.5156 - loss: 1.3701 - val_accuracy: 0.4999 - val_loss: 1.3094
# Epoch 17/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 951s 2s/step - accuracy: 0.4901 - loss: 1.3254 - val_accuracy: 0.5055 - val_loss: 1.2767
# Epoch 18/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.5000 - loss: 1.4275 - val_accuracy: 0.5008 - val_loss: 1.2826
# Epoch 19/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 949s 2s/step - accuracy: 0.5141 - loss: 1.2890 - val_accuracy: 0.5362 - val_loss: 1.2239
# Epoch 20/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 62s 131ms/step - accuracy: 0.4062 - loss: 1.3518 - val_accuracy: 0.5355 - val_loss: 1.2250
# Epoch 21/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1005s 2s/step - accuracy: 0.5309 - loss: 1.2355 - val_accuracy: 0.4888 - val_loss: 1.4226
# Epoch 22/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 59s 125ms/step - accuracy: 0.5469 - loss: 1.1767 - val_accuracy: 0.4897 - val_loss: 1.4160
# Epoch 23/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 914s 2s/step - accuracy: 0.5383 - loss: 1.2162 - val_accuracy: 0.5178 - val_loss: 1.3118
# Epoch 24/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 128ms/step - accuracy: 0.5469 - loss: 1.2227 - val_accuracy: 0.5171 - val_loss: 1.3112
# Epoch 25/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 907s 2s/step - accuracy: 0.5522 - loss: 1.1843 - val_accuracy: 0.5543 - val_loss: 1.1734
# Epoch 26/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.5938 - loss: 1.2537 - val_accuracy: 0.5540 - val_loss: 1.1758
# Epoch 27/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 912s 2s/step - accuracy: 0.5692 - loss: 1.1480 - val_accuracy: 0.5182 - val_loss: 1.3363
# Epoch 28/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.5625 - loss: 1.1556 - val_accuracy: 0.5188 - val_loss: 1.3277
# Epoch 29/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 908s 2s/step - accuracy: 0.5673 - loss: 1.1380 - val_accuracy: 0.5698 - val_loss: 1.1455
# Epoch 30/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 65s 140ms/step - accuracy: 0.6406 - loss: 1.0083 - val_accuracy: 0.5695 - val_loss: 1.1385
# Epoch 31/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1004s 2s/step - accuracy: 0.5851 - loss: 1.0992 - val_accuracy: 0.5695 - val_loss: 1.1331
# Epoch 32/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 63s 134ms/step - accuracy: 0.5469 - loss: 1.1726 - val_accuracy: 0.5698 - val_loss: 1.1336
# Epoch 33/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.5914 - loss: 1.0796 - val_accuracy: 0.5992 - val_loss: 1.0805
# Epoch 34/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 67s 142ms/step - accuracy: 0.5312 - loss: 1.1014 - val_accuracy: 0.5980 - val_loss: 1.0814
# Epoch 35/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 776s 2s/step - accuracy: 0.6045 - loss: 1.0483 - val_accuracy: 0.5863 - val_loss: 1.1078
# Epoch 36/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 51s 108ms/step - accuracy: 0.5156 - loss: 1.0631 - val_accuracy: 0.5866 - val_loss: 1.1128
# Epoch 37/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 857s 2s/step - accuracy: 0.6103 - loss: 1.0334 - val_accuracy: 0.5943 - val_loss: 1.1050
# Epoch 38/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 77s 164ms/step - accuracy: 0.5156 - loss: 1.4436 - val_accuracy: 0.5996 - val_loss: 1.0899
# Epoch 39/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1101s 2s/step - accuracy: 0.6221 - loss: 1.0018 - val_accuracy: 0.5922 - val_loss: 1.1153
# Epoch 40/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.6250 - loss: 0.9194 - val_accuracy: 0.5874 - val_loss: 1.1287
# Epoch 41/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1026s 2s/step - accuracy: 0.6322 - loss: 0.9787 - val_accuracy: 0.6107 - val_loss: 1.0551
# Epoch 42/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 66s 141ms/step - accuracy: 0.5938 - loss: 1.0709 - val_accuracy: 0.6124 - val_loss: 1.0527
# Epoch 43/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 958s 2s/step - accuracy: 0.6377 - loss: 0.9652 - val_accuracy: 0.6046 - val_loss: 1.0710
# Epoch 44/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 70s 149ms/step - accuracy: 0.6719 - loss: 1.0497 - val_accuracy: 0.6043 - val_loss: 1.0700
# Epoch 45/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1007s 2s/step - accuracy: 0.6455 - loss: 0.9426 - val_accuracy: 0.6112 - val_loss: 1.0579
# Epoch 46/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.5938 - loss: 1.1169 - val_accuracy: 0.6112 - val_loss: 1.0577
# Epoch 47/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 942s 2s/step - accuracy: 0.6523 - loss: 0.9196 - val_accuracy: 0.6136 - val_loss: 1.0656
# Epoch 48/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.5625 - loss: 1.0168 - val_accuracy: 0.6118 - val_loss: 1.0611
# Epoch 49/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 782s 2s/step - accuracy: 0.6604 - loss: 0.9068 - val_accuracy: 0.6188 - val_loss: 1.0558
# Epoch 50/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 50s 108ms/step - accuracy: 0.6406 - loss: 1.1232 - val_accuracy: 0.6186 - val_loss: 1.0530
# Epoch 51/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 972s 2s/step - accuracy: 0.6713 - loss: 0.8793 - val_accuracy: 0.6229 - val_loss: 1.0519
# Epoch 52/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 96s 206ms/step - accuracy: 0.7656 - loss: 0.6672 - val_accuracy: 0.6239 - val_loss: 1.0526
# Epoch 53/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1509s 3s/step - accuracy: 0.6767 - loss: 0.8603 - val_accuracy: 0.6149 - val_loss: 1.1014
# Epoch 54/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 79s 168ms/step - accuracy: 0.7344 - loss: 0.7098 - val_accuracy: 0.6146 - val_loss: 1.1032
# Epoch 55/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1122s 2s/step - accuracy: 0.6831 - loss: 0.8395 - val_accuracy: 0.6317 - val_loss: 1.0398
# Epoch 56/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 128ms/step - accuracy: 0.7188 - loss: 0.7207 - val_accuracy: 0.6316 - val_loss: 1.0405
# Epoch 57/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 941s 2s/step - accuracy: 0.6909 - loss: 0.8257 - val_accuracy: 0.6347 - val_loss: 1.0237
# Epoch 58/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 127ms/step - accuracy: 0.7812 - loss: 0.6569 - val_accuracy: 0.6342 - val_loss: 1.0223
# Epoch 59/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 1001s 2s/step - accuracy: 0.6979 - loss: 0.8000 - val_accuracy: 0.6299 - val_loss: 1.0314
# Epoch 60/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 60s 127ms/step - accuracy: 0.7656 - loss: 0.6838 - val_accuracy: 0.6302 - val_loss: 1.0304
# Epoch 61/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 901s 2s/step - accuracy: 0.7067 - loss: 0.7873 - val_accuracy: 0.6181 - val_loss: 1.0920
# Epoch 62/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 50s 107ms/step - accuracy: 0.7500 - loss: 0.6799 - val_accuracy: 0.6179 - val_loss: 1.0919
# Epoch 63/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 772s 2s/step - accuracy: 0.7217 - loss: 0.7602 - val_accuracy: 0.6380 - val_loss: 1.0084
# Epoch 64/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.7031 - loss: 0.9397 - val_accuracy: 0.6365 - val_loss: 1.0076
# Epoch 65/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 782s 2s/step - accuracy: 0.7210 - loss: 0.7484 - val_accuracy: 0.6343 - val_loss: 1.0591
# Epoch 66/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 50s 107ms/step - accuracy: 0.7344 - loss: 0.7180 - val_accuracy: 0.6332 - val_loss: 1.0637
# Epoch 67/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 770s 2s/step - accuracy: 0.7345 - loss: 0.7228 - val_accuracy: 0.6354 - val_loss: 1.0541
# Epoch 68/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 50s 106ms/step - accuracy: 0.7031 - loss: 0.7033 - val_accuracy: 0.6321 - val_loss: 1.0559
# Epoch 69/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 770s 2s/step - accuracy: 0.7390 - loss: 0.7002 - val_accuracy: 0.6450 - val_loss: 1.0356
# Epoch 70/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 50s 106ms/step - accuracy: 0.7500 - loss: 0.7855 - val_accuracy: 0.6454 - val_loss: 1.0343
# Epoch 71/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 771s 2s/step - accuracy: 0.7435 - loss: 0.6867 - val_accuracy: 0.6338 - val_loss: 1.0588
# Epoch 72/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 49s 105ms/step - accuracy: 0.7188 - loss: 0.7582 - val_accuracy: 0.6353 - val_loss: 1.0565
# Epoch 73/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 765s 2s/step - accuracy: 0.7511 - loss: 0.6704 - val_accuracy: 0.6480 - val_loss: 1.0344
# Epoch 74/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 54s 115ms/step - accuracy: 0.6562 - loss: 0.8235 - val_accuracy: 0.6505 - val_loss: 1.0328
# Epoch 75/75
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 767s 2s/step - accuracy: 0.7556 - loss: 0.6558 - val_accuracy: 0.6391 - val_loss: 1.0550

# %%
# save model structure in jason file
model_json = emotion_model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)

emotion_model.save_weights('.weights.h5')

# %%
history = emotion_model_info.history

plt.figure(figsize=(12, 4))
# Plotting accuracy
plt.subplot(1, 2, 1)
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting loss
plt.subplot(1, 2, 2)
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Mengambil prediksi dari model
validation_generator.reset()  # Reset generator untuk memastikan urutan yang benar
predictions = emotion_model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Mengambil label sebenarnya
true_classes = validation_generator.classes
class_labels = list(validation_generator.class_indices.keys())  # Mendapatkan nama kelas

# Menghitung confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Menampilkan confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 53s 455ms/step

# %%
label_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}
img = image.load_img("D:/Kuliah Files/Semester 7/Machine Learning/Emotion_detection_CNN/data/test/surprise/PublicTest_71260578.jpg",target_size = (48,48),color_mode = "grayscale")
img = np.array(img)
plt.imshow(img)
print(img.shape)
# Out:
# (48, 48)

# %%
mg = np.expand_dims(img,axis = 0) #makes image shape (1,48,48)
img = img.reshape(1,48,48,1)
result = emotion_model.predict(img)
result = list(result[0])
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# [np.float32(0.11961927), np.float32(0.0), np.float32(0.8803807), np.float32(0.0), np.float32(0.0), np.float32(0.0), np.float32(2.3307164e-36)]

# %%
img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# Fearful
